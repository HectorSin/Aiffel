# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

import tensorflow_datasets as tfds

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# GPU 확인
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# model.data 코드

# 데이터셋 불러오기
(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)

num_classes = ds_info.features["label"].num_classes

resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])
# Out:
# Downloading and preparing dataset 778.12 MiB (download: 778.12 MiB, generated: Unknown size, total: 778.12 MiB) to /root/tensorflow_datasets/stanford_dogs/0.2.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/12000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/stanford_dogs/incomplete.JZ6YWP_0.2.0/stanford_dogs-train.tfrecord*...:   …
# Generating test examples...:   0%|          | 0/8580 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/stanford_dogs/incomplete.JZ6YWP_0.2.0/stanford_dogs-test.tfrecord*...:   0…
# Dataset stanford_dogs downloaded and prepared to /root/tensorflow_datasets/stanford_dogs/0.2.0. Subsequent calls will reuse this data.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
# model.augmentat 코드

import random


# cutmix
def cutmix(image, label, prob = 1.0, batch_size = 16, img_size = 224):
    mixed_imgs = []
    mixed_labels = []

    for i in range(batch_size):
        image_a = image[i]
        label_a = label[i]
        j = tf.cast(tf.random.uniform([], 0, batch_size), tf.int32)
        image_b = image[j]
        label_b = label[j]
        x_min, y_min, x_max, y_max = get_clip_box(image_a, image_b)
        mixed_img, mixed_label = mixer(image_a, image_b, label_a, label_b, x_min, y_min, x_max, y_max)
        mixed_imgs.append(mixed_img)
        mixed_labels.append(mixed_label)

    mixed_imgs = tf.reshape(tf.stack(mixed_imgs), (batch_size, img_size, img_size, 3))
    mixed_labels = tf.reshape(tf.stack(mixed_labels), (batch_size, num_classes))
    return mixed_imgs, mixed_labels

# function for mixup
def mixup_2_images(image_a, image_b, label_a, label_b):
    ratio = tf.random.uniform([], 0, 1)

    if len(label_a.shape)==0:
        label_a = tf.one_hot(label_a, num_classes)
    if len(label_b.shape)==0:
        label_b = tf.one_hot(label_b, num_classes)
    mixed_image= (1-ratio)*image_a + ratio*image_b
    mixed_label = (1-ratio)*label_a + ratio*label_b

    return mixed_image, mixed_label

def mixup(image, label, prob=1.0, batch_size=16, img_size=224, num_classes=120):
    mixed_imgs = []
    mixed_labels = []

    for i in range(batch_size):
        image_a = image[i]
        label_a = label[i]
        j = tf.cast(tf.random.uniform([],0,batch_size), tf.int32)
        image_b = image[j]
        label_b = label[j]
        mixed_img, mixed_label = mixup_2_images(image_a, image_b, label_a, label_b)
        mixed_imgs.append(mixed_img)
        mixed_labels.append(mixed_label)

    mixed_imgs = tf.reshape(tf.stack(mixed_imgs), (batch_size, img_size, img_size, 3))
    mixed_labels = tf.reshape(tf.stack(mixed_labels), (batch_size, num_classes))
    return mixed_imgs, mixed_labels

"""
# augment
def augment(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, 0.2)
    image = tf.image.random_contrast(image, 0.2, 0.5)
    image = tf.image.random_hue(image, 0.2)
    image = tf.image.random_saturation(image, 0.2, 0.5)
    image = tf.clip_by_value(image, 0, 1)
    return image, label
"""

# augment with randomness
def augment(image, label):
    if random.choice([True, False]):
        image = tf.image.random_flip_left_right(image)
    if random.choice([True, False]):
        image = tf.image.random_flip_up_down(image)
    if random.choice([True, False]):
        brightness_factor = random.uniform(0, 0.2)
        image = tf.image.random_brightness(image, brightness_factor)
    if random.choice([True, False]):
        contrast_lower = random.uniform(0.2, 0.5)
        contrast_upper = random.uniform(contrast_lower, 0.5)
        image = tf.image.random_contrast(image, contrast_lower, contrast_upper)
    if random.choice([True, False]):
        hue_factor = random.uniform(0, 0.2)
        image = tf.image.random_hue(image, hue_factor)
    if random.choice([True, False]):
        saturation_lower = random.uniform(0.2, 0.5)
        saturation_upper = random.uniform(saturation_lower, 0.5)  # Ensure upper is always >= lower
        image = tf.image.random_saturation(image, saturation_lower, saturation_upper)
    image = tf.clip_by_value(image, 0, 1)
    return image, label

# %%
# model.base_code 코드
# 이미지의 박스를 구하는 함수
# 이미지의 크기를 입력받아서 박스의 좌표를 반환
def get_clip_box(image_a, image_b):
    # image.shape = (height, width, channel)
    image_size_x = image_a.shape[1]
    image_size_y = image_a.shape[0]

    # get center of box
    x = tf.cast(tf.random.uniform([], 0, image_size_x), tf.int32)
    y = tf.cast(tf.random.uniform([], 0, image_size_y), tf.int32)

    # get width, height of box
    width = tf.cast(image_size_x*tf.math.sqrt(1-tf.random.uniform([], 0, 1)), tf.int32)
    height = tf.cast(image_size_y*tf.math.sqrt(1-tf.random.uniform([], 0, 1)), tf.int32)

    # clip box in image and get minmax bbox
    x_min = tf.math.maximum(0, x-width//2)
    y_min = tf.math.maximum(0, y-height//2)
    x_max = tf.math.minimum(image_size_x, x+width//2)
    y_max = tf.math.minimum(image_size_y, y+height//2)

    return x_min, y_min, x_max, y_max

# mix two images
def mixer(image_a, image_b, label_a, label_b, x_min, y_min, x_max, y_max):
    image_size_x = image_a.shape[1]
    image_size_y = image_a.shape[0]

    # image_a의 박스 영역을 image_b의 박스 영역으로 바꾸기
    middle_left = image_a[y_min:y_max, 0:x_min, :] # image_b의 왼쪽 바깥 영역
    middle_center = image_b[y_min:y_max, x_min:x_max, :]  # image_b의 안쪽 영역
    middle_right = image_a[y_min:y_max, x_max:image_size_x, :] # image_b의 오른쪽 바깥 영역
    middle = tf.concat([middle_left,middle_center,middle_right], axis=1)
    top = image_a[0:y_min, :, :]
    bottom = image_a[y_max:image_size_y, :, :]
    mixed_img = tf.concat([top, middle, bottom],axis=0)

    # label_a와 label_b를 섞어서 반환
    mixed_area = (x_max-x_min)*(y_max-y_min)
    total_area = image_size_x*image_size_y
    ratio = tf.cast(mixed_area/total_area, tf.float32)

    if len(label_a.shape)==0:
        label_a = tf.one_hot(label_a, num_classes)
    if len(label_b.shape)==0:
        label_b = tf.one_hot(label_b, num_classes)
    mixed_label = (1-ratio)*label_a + ratio*label_b
    return mixed_img, mixed_label

# normalize and resize image [학습전 이미지 사이즈 조정]
def normalize_and_resize_img(image, label):
    image = tf.image.resize(image, [224, 224])
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

def onehot(image, label):
    label = tf.one_hot(label, num_classes)
    return image, label

# 전체 처리
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16, with_aug=False, with_cutmix=False, with_mixup=False):
    ds = ds.map(
        normalize_and_resize_img,
        num_parallel_calls=2
    )
    if not is_test and with_aug:
        ds = ds.map(
            augment,
            num_parallel_calls=2
        )
    ds = ds.batch(batch_size)
    if not is_test and with_cutmix:
        ds = ds.map(
            cutmix,
            num_parallel_calls=2
        )
    elif not is_test and with_mixup:
        ds = ds.map(
            mixup,
            num_parallel_calls=2
        )
    else:
        ds = ds.map(
            onehot,
            num_parallel_calls=2
        )
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
# 트레인 데이터셋
# ds_train_no_aug = apply_normalize_on_dataset(ds_train, with_aug=True, with_cutmix=False, with_mixup=False)
# ds_train_aug = apply_normalize_on_dataset(ds_train, with_aug=False, with_cutmix=False, with_mixup=False)
# ds_train_no_cutmix = apply_normalize_on_dataset(ds_train, with_aug=False, with_cutmix=False, with_mixup=False)
ds_train_cutmix = apply_normalize_on_dataset(ds_train, with_aug=False, with_cutmix=True, with_mixup=False)
# ds_train_aug_cutmix = apply_normalize_on_dataset(ds_train, with_aug=True, with_cutmix=True, with_mixup=False)
ds_train_mixup = apply_normalize_on_dataset(ds_train, with_aug=False, with_cutmix=False, with_mixup=True)

# 테스트 데이터셋
ds_test = apply_normalize_on_dataset(ds_test, is_test=True)

# %%
resnet50_cutmix = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

resnet50_mixup = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

"""
resnet50_no_aug = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])
resnet50_aug = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])
resnet50_no_cutmix = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

resnet50_aug_cutmix = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])
"""
# Out:
# "\nresnet50_no_aug = keras.models.Sequential([\n    keras.applications.resnet.ResNet50(\n        include_top=False,\n        weights='imagenet',\n        input_shape=(224,224,3),\n        pooling='avg',\n    ),\n    keras.layers.Dense(num_classes, activation='softmax')\n])\nresnet50_aug = keras.models.Sequential([\n    keras.applications.resnet.ResNet50(\n        include_top=False,\n        weights='imagenet',\n        input_shape=(224,224,3),\n        pooling='avg',\n    ),\n    keras.layers.Dense(num_classes, activation='softmax')\n])\nresnet50_no_cutmix = keras.models.Sequential([\n    keras.applications.resnet.ResNet50(\n        include_top=False,\n        weights='imagenet',\n        input_shape=(224,224,3),\n        pooling='avg',\n    ),\n    keras.layers.Dense(num_classes, activation='softmax')\n])\n\nresnet50_aug_cutmix = keras.models.Sequential([\n    keras.applications.resnet.ResNet50(\n        include_top=False,\n        weights='imagenet',\n        input_shape=(224,224,3),\n        pooling='avg',\n    ),\n    keras.layers.Dense(num_classes, activation='softmax')\n])\n"

# %%
EPOCH = 50

# %%
model_list = [resnet50_cutmix, resnet50_mixup]

for res_model in model_list:
    res_model.compile(
        loss='categorical_crossentropy',
        optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
        metrics=['accuracy'],
    )


history_cutmix = resnet50_cutmix.fit(
    ds_train_cutmix,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)


history_mixup = resnet50_mixup.fit(
    ds_train_mixup,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
"""
history_no_aug = resnet50_no_aug.fit(
    ds_train_no_aug,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

history_aug = resnet50_aug.fit(
    ds_train_aug,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

history_no_cutmix = resnet50_no_cutmix.fit(
    ds_train_no_cutmix,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)


history_aug_cutmix = resnet50_aug_cutmix.fit(
    ds_train_aug_cutmix,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
"""
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/50
# 750/750 [==============================] - 94s 97ms/step - loss: 1.8191 - accuracy: 0.7854 - val_loss: 1.1545 - val_accuracy: 0.7015
# Epoch 2/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.8020 - accuracy: 0.7934 - val_loss: 1.1815 - val_accuracy: 0.7084
# Epoch 3/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.7655 - accuracy: 0.7946 - val_loss: 1.1876 - val_accuracy: 0.6995
# Epoch 4/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.7620 - accuracy: 0.7974 - val_loss: 1.2089 - val_accuracy: 0.6960
# Epoch 5/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.7416 - accuracy: 0.7947 - val_loss: 1.1911 - val_accuracy: 0.6989
# Epoch 6/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.7009 - accuracy: 0.8125 - val_loss: 1.2896 - val_accuracy: 0.6763
# Epoch 7/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.6887 - accuracy: 0.8107 - val_loss: 1.2726 - val_accuracy: 0.6912
# Epoch 8/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6913 - accuracy: 0.8104 - val_loss: 1.2435 - val_accuracy: 0.6952
# Epoch 9/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6651 - accuracy: 0.8133 - val_loss: 1.2186 - val_accuracy: 0.7050
# Epoch 10/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6675 - accuracy: 0.8112 - val_loss: 1.2848 - val_accuracy: 0.6932
# Epoch 11/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6580 - accuracy: 0.8100 - val_loss: 1.3640 - val_accuracy: 0.6757
# Epoch 12/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6401 - accuracy: 0.8176 - val_loss: 1.2622 - val_accuracy: 0.6933
# Epoch 13/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6186 - accuracy: 0.8192 - val_loss: 1.2859 - val_accuracy: 0.6839
# Epoch 14/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5982 - accuracy: 0.8210 - val_loss: 1.2615 - val_accuracy: 0.6992
# Epoch 15/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6075 - accuracy: 0.8202 - val_loss: 1.3158 - val_accuracy: 0.6955
# Epoch 16/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5997 - accuracy: 0.8164 - val_loss: 1.2478 - val_accuracy: 0.7003
# Epoch 17/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5670 - accuracy: 0.8276 - val_loss: 1.2465 - val_accuracy: 0.7020
# Epoch 18/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5678 - accuracy: 0.8256 - val_loss: 1.3559 - val_accuracy: 0.6894
# Epoch 19/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5581 - accuracy: 0.8289 - val_loss: 1.4378 - val_accuracy: 0.6709
# Epoch 20/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5243 - accuracy: 0.8326 - val_loss: 1.2844 - val_accuracy: 0.6918
# Epoch 21/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5358 - accuracy: 0.8311 - val_loss: 1.2195 - val_accuracy: 0.7146
# Epoch 22/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5051 - accuracy: 0.8359 - val_loss: 1.2643 - val_accuracy: 0.7079
# Epoch 23/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4884 - accuracy: 0.8370 - val_loss: 1.2989 - val_accuracy: 0.7018
# Epoch 24/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5050 - accuracy: 0.8354 - val_loss: 1.3002 - val_accuracy: 0.6996
# Epoch 25/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4761 - accuracy: 0.8484 - val_loss: 1.4852 - val_accuracy: 0.6609
# Epoch 26/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4993 - accuracy: 0.8257 - val_loss: 1.4284 - val_accuracy: 0.6744
# Epoch 27/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4795 - accuracy: 0.8379 - val_loss: 1.2977 - val_accuracy: 0.7032
# Epoch 28/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4763 - accuracy: 0.8312 - val_loss: 1.2604 - val_accuracy: 0.7104
# Epoch 29/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4767 - accuracy: 0.8340 - val_loss: 1.2689 - val_accuracy: 0.7095
# Epoch 30/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4557 - accuracy: 0.8380 - val_loss: 1.3433 - val_accuracy: 0.6930
# Epoch 31/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.4453 - accuracy: 0.8357 - val_loss: 1.3497 - val_accuracy: 0.6982
# Epoch 32/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4347 - accuracy: 0.8411 - val_loss: 1.3263 - val_accuracy: 0.7022
# Epoch 33/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4273 - accuracy: 0.8410 - val_loss: 1.4150 - val_accuracy: 0.6834
# Epoch 34/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.4155 - accuracy: 0.8412 - val_loss: 1.3873 - val_accuracy: 0.6881
# Epoch 35/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4120 - accuracy: 0.8392 - val_loss: 1.3576 - val_accuracy: 0.7031
# Epoch 36/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4201 - accuracy: 0.8357 - val_loss: 1.3612 - val_accuracy: 0.6978
# Epoch 37/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.3980 - accuracy: 0.8455 - val_loss: 1.3645 - val_accuracy: 0.6927
# Epoch 38/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.3753 - accuracy: 0.8478 - val_loss: 1.4088 - val_accuracy: 0.6906
# Epoch 39/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.3606 - accuracy: 0.8498 - val_loss: 1.3931 - val_accuracy: 0.6959
# Epoch 40/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.3742 - accuracy: 0.8445 - val_loss: 1.3862 - val_accuracy: 0.6934
# Epoch 41/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.3544 - accuracy: 0.8475 - val_loss: 1.5558 - val_accuracy: 0.6518
# Epoch 42/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.3591 - accuracy: 0.8430 - val_loss: 1.3631 - val_accuracy: 0.7048
# Epoch 43/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.3436 - accuracy: 0.8420 - val_loss: 1.3037 - val_accuracy: 0.7073
# Epoch 44/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.3752 - accuracy: 0.8356 - val_loss: 1.3414 - val_accuracy: 0.7031
# Epoch 45/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.3577 - accuracy: 0.8417 - val_loss: 1.4769 - val_accuracy: 0.6837
# Epoch 46/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.3145 - accuracy: 0.8550 - val_loss: 1.4173 - val_accuracy: 0.6918
# Epoch 47/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.3128 - accuracy: 0.8491 - val_loss: 1.3146 - val_accuracy: 0.7115
# Epoch 48/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.3341 - accuracy: 0.8462 - val_loss: 1.3809 - val_accuracy: 0.6936
# Epoch 49/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.3131 - accuracy: 0.8515 - val_loss: 1.3818 - val_accuracy: 0.6995
# Epoch 50/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.3034 - accuracy: 0.8469 - val_loss: 1.4618 - val_accuracy: 0.6860
# Epoch 1/50
# 750/750 [==============================] - 94s 97ms/step - loss: 1.8626 - accuracy: 0.8357 - val_loss: 1.2711 - val_accuracy: 0.6690
# Epoch 2/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.8766 - accuracy: 0.8375 - val_loss: 1.2439 - val_accuracy: 0.6720
# Epoch 3/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.8808 - accuracy: 0.8343 - val_loss: 1.2611 - val_accuracy: 0.6734
# Epoch 4/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.8459 - accuracy: 0.8426 - val_loss: 1.2755 - val_accuracy: 0.6789
# Epoch 5/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.8332 - accuracy: 0.8406 - val_loss: 1.2859 - val_accuracy: 0.6704
# Epoch 6/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.8274 - accuracy: 0.8427 - val_loss: 1.2481 - val_accuracy: 0.6786
# Epoch 7/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.8348 - accuracy: 0.8442 - val_loss: 1.3069 - val_accuracy: 0.6693
# Epoch 8/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.7926 - accuracy: 0.8540 - val_loss: 1.2887 - val_accuracy: 0.6765
# Epoch 9/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.8115 - accuracy: 0.8473 - val_loss: 1.2548 - val_accuracy: 0.6818
# Epoch 10/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.7661 - accuracy: 0.8508 - val_loss: 1.2872 - val_accuracy: 0.6807
# Epoch 11/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.7513 - accuracy: 0.8621 - val_loss: 1.3232 - val_accuracy: 0.6783
# Epoch 12/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.7230 - accuracy: 0.8646 - val_loss: 1.3682 - val_accuracy: 0.6617
# Epoch 13/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.7311 - accuracy: 0.8580 - val_loss: 1.3447 - val_accuracy: 0.6671
# Epoch 14/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.7127 - accuracy: 0.8584 - val_loss: 1.3292 - val_accuracy: 0.6730
# Epoch 15/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.7016 - accuracy: 0.8672 - val_loss: 1.2969 - val_accuracy: 0.6800
# Epoch 16/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.7246 - accuracy: 0.8542 - val_loss: 1.3330 - val_accuracy: 0.6719
# Epoch 17/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.7153 - accuracy: 0.8668 - val_loss: 1.3379 - val_accuracy: 0.6757
# Epoch 18/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.7232 - accuracy: 0.8675 - val_loss: 1.3174 - val_accuracy: 0.6734
# Epoch 19/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6873 - accuracy: 0.8666 - val_loss: 1.3278 - val_accuracy: 0.6692
# Epoch 20/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6908 - accuracy: 0.8664 - val_loss: 1.3234 - val_accuracy: 0.6735
# Epoch 21/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.6795 - accuracy: 0.8679 - val_loss: 1.2922 - val_accuracy: 0.6804
# Epoch 22/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6880 - accuracy: 0.8653 - val_loss: 1.3459 - val_accuracy: 0.6694
# Epoch 23/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6696 - accuracy: 0.8705 - val_loss: 1.3693 - val_accuracy: 0.6692
# Epoch 24/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6831 - accuracy: 0.8643 - val_loss: 1.3421 - val_accuracy: 0.6678
# Epoch 25/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.6515 - accuracy: 0.8686 - val_loss: 1.3441 - val_accuracy: 0.6720
# Epoch 26/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.6472 - accuracy: 0.8742 - val_loss: 1.3366 - val_accuracy: 0.6782
# Epoch 27/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.6092 - accuracy: 0.8757 - val_loss: 1.3684 - val_accuracy: 0.6667
# Epoch 28/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.6041 - accuracy: 0.8786 - val_loss: 1.4266 - val_accuracy: 0.6522
# Epoch 29/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6302 - accuracy: 0.8723 - val_loss: 1.3951 - val_accuracy: 0.6594
# Epoch 30/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6168 - accuracy: 0.8735 - val_loss: 1.4292 - val_accuracy: 0.6500
# Epoch 31/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6083 - accuracy: 0.8793 - val_loss: 1.3518 - val_accuracy: 0.6719
# Epoch 32/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5912 - accuracy: 0.8786 - val_loss: 1.3544 - val_accuracy: 0.6698
# Epoch 33/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.5579 - accuracy: 0.8806 - val_loss: 1.4431 - val_accuracy: 0.6465
# Epoch 34/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.6038 - accuracy: 0.8723 - val_loss: 1.3612 - val_accuracy: 0.6772
# Epoch 35/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.5994 - accuracy: 0.8808 - val_loss: 1.3419 - val_accuracy: 0.6749
# Epoch 36/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5470 - accuracy: 0.8855 - val_loss: 1.4056 - val_accuracy: 0.6622
# Epoch 37/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.5852 - accuracy: 0.8777 - val_loss: 1.3615 - val_accuracy: 0.6776
# Epoch 38/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.5854 - accuracy: 0.8792 - val_loss: 1.3516 - val_accuracy: 0.6807
# Epoch 39/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5796 - accuracy: 0.8803 - val_loss: 1.4131 - val_accuracy: 0.6625
# Epoch 40/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.5934 - accuracy: 0.8740 - val_loss: 1.4727 - val_accuracy: 0.6508
# Epoch 41/50
# 750/750 [==============================] - 71s 95ms/step - loss: 1.5487 - accuracy: 0.8888 - val_loss: 1.3860 - val_accuracy: 0.6781
# Epoch 42/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5607 - accuracy: 0.8857 - val_loss: 1.3683 - val_accuracy: 0.6698
# Epoch 43/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5387 - accuracy: 0.8834 - val_loss: 1.3809 - val_accuracy: 0.6662
# Epoch 44/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5299 - accuracy: 0.8863 - val_loss: 1.4166 - val_accuracy: 0.6695
# Epoch 45/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5422 - accuracy: 0.8825 - val_loss: 1.3884 - val_accuracy: 0.6684
# Epoch 46/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5412 - accuracy: 0.8795 - val_loss: 1.4403 - val_accuracy: 0.6614
# Epoch 47/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.5451 - accuracy: 0.8803 - val_loss: 1.3869 - val_accuracy: 0.6715
# Epoch 48/50
# 750/750 [==============================] - 72s 95ms/step - loss: 1.5418 - accuracy: 0.8775 - val_loss: 1.4212 - val_accuracy: 0.6554
# Epoch 49/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4874 - accuracy: 0.8947 - val_loss: 1.3968 - val_accuracy: 0.6673
# Epoch 50/50
# 750/750 [==============================] - 72s 96ms/step - loss: 1.4938 - accuracy: 0.8867 - val_loss: 1.4847 - val_accuracy: 0.6460
# "\nhistory_no_aug = resnet50_no_aug.fit(\n    ds_train_no_aug,\n    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),\n    validation_steps=int(ds_info.splits['test'].num_examples/16),\n    epochs=EPOCH,\n    validation_data=ds_test,\n    verbose=1,\n    use_multiprocessing=True,\n)\n\nhistory_aug = resnet50_aug.fit(\n    ds_train_aug,\n    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),\n    validation_steps=int(ds_info.splits['test'].num_examples/16),\n    epochs=EPOCH,\n    validation_data=ds_test,\n    verbose=1,\n    use_multiprocessing=True,\n)\n\nhistory_no_cutmix = resnet50_no_cutmix.fit(\n    ds_train_no_cutmix,\n    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),\n    validation_steps=int(ds_info.splits['test'].num_examples/16),\n    epochs=EPOCH,\n    validation_data=ds_test,\n    verbose=1,\n    use_multiprocessing=True,\n)\n\n\nhistory_aug_cutmix = resnet50_aug_cutmix.fit(\n    ds_train_aug_cutmix,\n    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),\n    validation_steps=int(ds_info.splits['test'].num_examples/16),\n    epochs=EPOCH,\n    validation_data=ds_test,\n    verbose=1,\n    use_multiprocessing=True,\n)\n"

# %%
plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(history_mixup.history['loss'], 'b-', label='mixup_loss')
plt.plot(history_mixup.history['val_loss'], 'b--', label='mixup_val_loss')
plt.plot(history_cutmix.history['loss'], 'r-', label='cutmix_loss')
plt.plot(history_cutmix.history['val_loss'], 'r--', label='cutmix_val_loss')
plt.xlabel('Epoch')
plt.title('Loss')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(history_mixup.history['accuracy'], 'g-', label='mixup_accuracy')
plt.plot(history_mixup.history['val_accuracy'], 'g--', label='mixup_val_accuracy')
plt.plot(history_cutmix.history['accuracy'], 'y-', label='cutmix_accuracy')
plt.plot(history_cutmix.history['val_accuracy'], 'y--', label='cutmix_val_accuracy')
plt.xlabel('Epoch')
plt.title('Accuracy')
plt.legend()
